# %% [markdown]
# <a href="https://colab.research.google.com/github/juancasi/artificial_intelligence/blob/main/chapter_04/10_numpy_joining_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NumPy Joining Array

# %% [markdown]
# ##Joining NumPy Arrays
# Joining means putting contents of two or more arrays in a single array.
#
# In SQL we join tables based on a key, whereas in NumPy we join arrays by axes.
#
# We pass a sequence of arrays that we want to join to the concatenate() function, along with the axis. If axis is not explicitly passed, it is taken as 0.

# %% [markdown]
# **Example**
#
# Join two arrays

# %%
import numpy as np

arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

arr = np.concatenate((arr1, arr2))

print(arr)
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# **Example**
#
# Join two 2-D arrays along rows (axis=1):

# %%
import numpy as np

arr1 = np.array([[1, 2], [3, 4]])

arr2 = np.array([[5, 6], [7, 8]])

arr = np.concatenate((arr1, arr2), axis=1)

print(arr)
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %% [markdown]
# ##Joining Arrays Using Stack Functions
# Stacking is same as concatenation, the only difference is that stacking is done along a new axis.
#
# We can concatenate two 1-D arrays along the second axis which would result in putting them one over the other, ie. stacking.
#
# We pass a sequence of arrays that we want to join to the concatenate() method along with the axis. If axis is not explicitly passed it is taken as 0.

# %% [markdown]
# **Example**

# %%
import numpy as np

arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])
arr = np.stack((arr1, arr2), axis=1)
print(arr)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# ##Stacking Along Rows
# NumPy provides a helper function: hstack() to stack along rows.

# %% [markdown]
# **Example**

# %%
import numpy as np

arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

arr = np.hstack((arr1, arr2))

print(arr)
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# ##Stacking Along Columns
# NumPy provides a helper function: vstack()  to stack along columns.

# %% [markdown]
# **Example**

# %%
import numpy as np

arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

arr = np.vstack((arr1, arr2))

print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ##Stacking Along Height (depth)
# NumPy provides a helper function: dstack() to stack along height, which is the same as depth.

# %% [markdown]
# **Example**

# %%
import numpy as np

arr1 = np.array([1, 2, 3])

arr2 = np.array([4, 5, 6])

arr = np.dstack((arr1, arr2))

print(arr)
# Out:
# [[[1 4]
#   [2 5]
#   [3 6]]]

# %%
import matplotlib.pyplot as plt

# %%
image1 = plt.imread("/content/car1.jpeg")
print(type(image1))
# Out:
# <class 'numpy.ndarray'>

# %%
image1.shape
# Out:
# (168, 300, 3)

# %%
image2 = plt.imread("/content/car2.jpeg")
image2.shape
# Out:
# (168, 300, 3)

# %%
vimage = np.vstack((image1, image2))
print(vimage.shape)
# Out:
# (336, 300, 3)

# %%
plt.imshow(vimage)
plt.show()

# %%
image3 = image1[42:126,75:225,:]
print(image1.shape, image3.shape)
plt.imshow(image3)
plt.show()
# Out:
# (168, 300, 3) (84, 150, 3)

# %%
parts = np.array_split(image1, 9)
for part in parts:
  plt.imshow(part)
  plt.show()

# %%
parts = []
rows = np.vsplit(image1, 3)
for row in rows:
  cols = np.hsplit(row, 3)
  for part in cols:
    parts.append(part)
    plt.imshow(part)
    plt.show()

# %%
v1 = np.hstack((parts[0], parts[1], parts[2]))
v2 = np.hstack((parts[3], parts[4], parts[5]))
v3 = np.hstack((parts[6], parts[7], parts[8]))
vh = np.vstack((v1,v2,v3))
plt.imshow(vh)
plt.show()
